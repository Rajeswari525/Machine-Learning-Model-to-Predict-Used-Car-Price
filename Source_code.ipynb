# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,classification_report
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import math

# %%
df = pd.read_excel(r'Data_Train.xlsx')
df1 = pd.read_excel(r'Data_Test.xlsx')

# %% [markdown]
# # DATA EXPLORATION

# %% [markdown]
# ## Printing No. of Rows and No. of Colulmns in Train and Test DataSets

# %%
print(df.shape)
print(df1.shape)
# Out:
# (6019, 13)
# (1234, 12)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %%
df1.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %% [markdown]
# #### Categorical Columns: Owner_type,Fuel_type,transmission ,Name,loaction
# #### Continuous Columns: Year,Kilometers_driven,MIleage,engine,power,price

# %% [markdown]
# ## No. of Missing Values in Train and Test DataSets

# %%
print(df.isna().sum())
print(df1.isna().sum())
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %% [markdown]
# ## Cleaning Text Data And Imputing Missing Values with median

# %%
df = df.drop(columns = ['New_Price'] )
df1 = df1.drop(columns = ['New_Price'])

# %%
le = preprocessing.LabelEncoder()
iteration={'Fuel_Type','Location','Transmission','Owner_Type'}
for i in iteration: 
    df[i] = le.fit_transform(df[i])

# %%
le1 = preprocessing.LabelEncoder()
iteration={'Fuel_Type','Location','Transmission','Owner_Type'}
for i in iteration: 
    df1[i] = le1.fit_transform(df1[i])

# %%
x=df['Name']
a=[]
for k in range(len(x)):
    a=list(x[k].split(' ',2))
    df.loc[k,'Brand']=a[0]
    df.loc[k,'Model']=a[1]
    df.loc[k,'Version']=str(a[2])
df = df.drop(columns = ['Name'])
df.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         9  2010              72000          0             1           0
# 1        10  2015              41000          1             1           0
# 2         2  2011              46000          4             1           0
# 3         2  2012              87000          1             1           0
# 4         3  2013              40670          1             0           2
#
#       Mileage   Engine      Power  Seats  Price    Brand   Model  \
# 0  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75   Maruti   Wagon
# 1  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50  Hyundai   Creta
# 2   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50    Honda    Jazz
# 3  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00   Maruti  Ertiga
# 4   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74     Audi      A4
#
#                    Version
# 0                R LXI CNG
# 1       1.6 CRDi SX Option
# 2                        V
# 3                      VDI
# 4  New 2.0 TDI Multitronic

# %%
x=df1['Name']
a=[]
for k in range(len(x)):
    a=list(x[k].split(' ',2))
    df1.loc[k,'Brand']=a[0]
    if len(a)==3:
        df1.loc[k,'Model']=a[1]
    df1.loc[k,'Version']=a[len(a)-1]
df1 = df1.drop(columns = ['Name'])
df1.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         4  2014              40929          0             1           0
# 1         3  2013              54493          3             1           2
# 2         9  2017              34000          1             1           0
# 3         5  2012             139000          1             1           0
# 4         9  2014              29000          3             1           0
#
#        Mileage   Engine      Power  Seats    Brand   Model  \
# 0  32.26 km/kg   998 CC   58.2 bhp    4.0   Maruti    Alto
# 1    24.7 kmpl   796 CC   47.3 bhp    5.0   Maruti    Alto
# 2   13.68 kmpl  2393 CC  147.8 bhp    7.0   Toyota  Innova
# 3   23.59 kmpl  1364 CC   null bhp    5.0   Toyota   Etios
# 4    18.5 kmpl  1197 CC  82.85 bhp    5.0  Hyundai     i20
#
#                        Version
# 0                  K10 LXI CNG
# 1            800 2016-2019 LXI
# 2  Crysta Touring Sport 2.4 MT
# 3                      Liva GD
# 4                        Magna

# %%
iteration2={'Mileage','Engine','Power'}
for i in iteration2:
    new=df[i].str.split(" ",expand=True)
    new1=df1[i].str.split(" ",expand=True)
    df1[i]=pd.to_numeric(new1[0],errors='coercive')
    df[i]=pd.to_numeric(new[0],errors='coercive')
    df[i].fillna(df[i].astype("float64").median(),inplace=True)
    df1[i].fillna(df1[i].astype("float64").median(),inplace=True)
df['Seats'].fillna(df['Seats'].astype("float64").median(),inplace=True)
df1['Seats'].fillna(df1['Seats'].astype("float64").median() , inplace = True)

# %%
df.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         9  2010              72000          0             1           0
# 1        10  2015              41000          1             1           0
# 2         2  2011              46000          4             1           0
# 3         2  2012              87000          1             1           0
# 4         3  2013              40670          1             0           2
#
#    Mileage  Engine   Power  Seats  Price    Brand   Model  \
# 0    26.60   998.0   58.16    5.0   1.75   Maruti   Wagon
# 1    19.67  1582.0  126.20    5.0  12.50  Hyundai   Creta
# 2    18.20  1199.0   88.70    5.0   4.50    Honda    Jazz
# 3    20.77  1248.0   88.76    7.0   6.00   Maruti  Ertiga
# 4    15.20  1968.0  140.80    5.0  17.74     Audi      A4
#
#                    Version
# 0                R LXI CNG
# 1       1.6 CRDi SX Option
# 2                        V
# 3                      VDI
# 4  New 2.0 TDI Multitronic

# %% [markdown]
# ####                           no missing values

# %%
print("\t          train_data")
print(df.isna().sum())
print(" \t        test_data")
print(df1.isna().sum())
# Out:
# 	          train_data
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Brand                0
# Model                0
# Version              0
# dtype: int64
#  	        test_data
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Brand                0
# Model                1
# Version              0
# dtype: int64

# %% [markdown]
# ## Outlier Detection

# %%
ax=sns.scatterplot(x="Year", y="Price", data=df)

# %%
ax=sns.scatterplot(x="Kilometers_Driven", y="Price", data=df)

# %%
ax=sns.scatterplot(x="Mileage", y="Price", data=df)

# %%
ax=sns.scatterplot(x="Power", y="Price", data=df)

# %% [markdown]
# ##  Relation between features of given dataset

# %%
col = df.columns
sns.pairplot( df[col]  ,height = 2.5)

# %%
plt.subplots(figsize = (11,11))
corrmatrix = df.corr()
sns.heatmap(corrmatrix ,square = True,annot = True , fmt = '.3f')

# %%
corrmatrix
# Out:
#                    Location      Year  Kilometers_Driven  Fuel_Type  \
# Location           1.000000 -0.020117          -0.042751   0.115048
# Year              -0.020117  1.000000          -0.173048  -0.129526
# Kilometers_Driven -0.042751 -0.173048           1.000000  -0.102953
# Fuel_Type          0.115048 -0.129526          -0.102953   1.000000
# Transmission       0.040174 -0.097059           0.025663   0.125219
# Owner_Type        -0.033889 -0.386160           0.079924   0.043017
# Mileage            0.018773  0.321534          -0.065253  -0.152125
# Engine            -0.078600 -0.050086           0.090890  -0.401784
# Power             -0.065482  0.024195           0.032080  -0.265898
# Seats             -0.037607  0.015204           0.082782  -0.299306
# Price             -0.116620  0.305327          -0.011493  -0.305207
#
#                    Transmission  Owner_Type   Mileage    Engine     Power  \
# Location               0.040174   -0.033889  0.018773 -0.078600 -0.065482
# Year                  -0.097059   -0.386160  0.321534 -0.050086  0.024195
# Kilometers_Driven      0.025663    0.079924 -0.065253  0.090890  0.032080
# Fuel_Type              0.125219    0.043017 -0.152125 -0.401784 -0.265898
# Transmission           1.000000    0.003002  0.333094 -0.499194 -0.640873
# Owner_Type             0.003002    1.000000 -0.154188  0.047847  0.024566
# Mileage                0.333094   -0.154188  1.000000 -0.586404 -0.497666
# Engine                -0.499194    0.047847 -0.586404  1.000000  0.860410
# Power                 -0.640873    0.024566 -0.497666  0.860410  1.000000
# Seats                  0.074838    0.002219 -0.299632  0.393368  0.102470
# Price                 -0.586025   -0.094559 -0.306588  0.657347  0.769711
#
#                       Seats     Price
# Location          -0.037607 -0.116620
# Year               0.015204  0.305327
# Kilometers_Driven  0.082782 -0.011493
# Fuel_Type         -0.299306 -0.305207
# Transmission       0.074838 -0.586025
# Owner_Type         0.002219 -0.094559
# Mileage           -0.299632 -0.306588
# Engine             0.393368  0.657347
# Power              0.102470  0.769711
# Seats              1.000000  0.052811
# Price              0.052811  1.000000

# %% [markdown]
# # Data Cleaning And Preprocessing

# %% [markdown]
# ## Label Encoding

# %%
df1['Model']=df1['Model'].fillna(method='ffill')

# %%
le = preprocessing.LabelEncoder()
iteration={'Brand','Model','Version'}
for i in iteration: 
    df[i] = le.fit_transform(df[i])

# %%
le = preprocessing.LabelEncoder()
iteration={'Brand','Model','Version'}
for i in iteration: 
    df1[i] = le.fit_transform(df1[i])

# %% [markdown]
# ## Normalization

# %%
x = df.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)
df.columns=['Location','Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price', 'Brand', 'Model','Version']
df.head()
# Out:
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0       0.9  0.571429           0.011051       0.00           1.0    0.000000
# 1       1.0  0.809524           0.006282       0.25           1.0    0.000000
# 2       0.2  0.619048           0.007051       1.00           1.0    0.000000
# 3       0.2  0.666667           0.013359       0.25           1.0    0.000000
# 4       0.3  0.714286           0.006231       0.25           0.0    0.666667
#
#     Mileage    Engine     Power  Seats     Price     Brand     Model   Version
# 0  0.793083  0.156261  0.045569    0.5  0.008210  0.600000  0.895735  0.700058
# 1  0.586464  0.254809  0.174971    0.5  0.075583  0.333333  0.251185  0.128382
# 2  0.542636  0.190179  0.103652    0.5  0.025445  0.300000  0.469194  0.835924
# 3  0.619261  0.198448  0.103766    0.7  0.034846  0.600000  0.327014  0.850892
# 4  0.453190  0.319946  0.202739    0.5  0.108423  0.033333  0.047393  0.668969

# %% [markdown]
# ## Clipping Outliers

# %% [markdown]
# ## using the z- score

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
df.head()
np.max(df)
z
# Out:
# array([[1.14365818, 1.02713851, 0.14531489, ..., 0.33132605, 1.2290421 ,
#         0.58198804],
#        [1.48198899, 0.50216112, 0.19436922, ..., 0.66226004, 0.84698996,
#         1.36909725],
#        [1.22465746, 0.72127858, 0.13958146, ..., 0.7864583 , 0.14480264,
#         1.04569008],
#        ...,
#        [0.12866576, 0.41541866, 0.0409635 , ..., 0.20712779, 1.45801622,
#         0.12928374],
#        [0.80532737, 0.10955873, 0.13958146, ..., 0.33132605, 1.2290421 ,
#         0.59574191],
#        [0.20966505, 0.72127858, 0.12862391, ..., 1.4074496 , 1.25914338,
#         0.08016276]])

# %%
threshold = 3
df = df[(z < 3).all(axis=1)]
df.head()
# Out:
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0       0.9  0.571429           0.011051       0.00           1.0    0.000000
# 1       1.0  0.809524           0.006282       0.25           1.0    0.000000
# 2       0.2  0.619048           0.007051       1.00           1.0    0.000000
# 3       0.2  0.666667           0.013359       0.25           1.0    0.000000
# 4       0.3  0.714286           0.006231       0.25           0.0    0.666667
#
#     Mileage    Engine     Power  Seats     Price     Brand     Model   Version
# 0  0.793083  0.156261  0.045569    0.5  0.008210  0.600000  0.895735  0.700058
# 1  0.586464  0.254809  0.174971    0.5  0.075583  0.333333  0.251185  0.128382
# 2  0.542636  0.190179  0.103652    0.5  0.025445  0.300000  0.469194  0.835924
# 3  0.619261  0.198448  0.103766    0.7  0.034846  0.600000  0.327014  0.850892
# 4  0.453190  0.319946  0.202739    0.5  0.108423  0.033333  0.047393  0.668969

# %% [markdown]
# # Idntifying Correlation Between Input and Output Variables using Chi-SquareTest

# %%
x=['Year','Location','Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Brand', 'Model','Version']

# %%
l=[]
from scipy import stats
for i in x:
    statistic,p,dof,freq=stats.chi2_contingency(pd.crosstab(df[i],df['Price']))
    prob=0.90
    alpha=1-prob
    critical=stats.chi2.ppf(prob,dof)
    if abs(statistic)>=critical:
        l.append(i)
        print(i,":dependant")
    else:
        print(i,":independant")
    if p<=alpha:
        print(i,":dependant")
    else:
        print(i,":independent")   
l
# Out:
# Year :dependant
# Year :dependant
# Location :dependant
# Location :dependant
# Kilometers_Driven :dependant
# Kilometers_Driven :dependant
# Fuel_Type :independant
# Fuel_Type :independent
# Transmission :dependant
# Transmission :dependant
# Owner_Type :independant
# Owner_Type :independent
# Mileage :dependant
# Mileage :dependant
# Engine :dependant
# Engine :dependant
# Power :dependant
# Power :dependant
# Seats :dependant
# Seats :dependant
# Brand :dependant
# Brand :dependant
# Model :dependant
# Model :dependant
# Version :dependant
# Version :dependant
# ['Year',
#  'Location',
#  'Kilometers_Driven',
#  'Transmission',
#  'Mileage',
#  'Engine',
#  'Power',
#  'Seats',
#  'Brand',
#  'Model',
#  'Version']

# %% [markdown]
# The Features which are dependant only taken for training the model

# %%
prc=df['Price']
df=df.drop(columns=['Fuel_Type','Owner_Type','Price'])

# %%
df1=df1.drop(columns=['Fuel_Type','Owner_Type'])

# %%
df=pd.concat([df,prc],axis=1)

# %%
df.head()
# Out:
#    Location      Year  Kilometers_Driven  Transmission   Mileage    Engine  \
# 0       0.9  0.571429           0.011051           1.0  0.793083  0.156261
# 1       1.0  0.809524           0.006282           1.0  0.586464  0.254809
# 2       0.2  0.619048           0.007051           1.0  0.542636  0.190179
# 3       0.2  0.666667           0.013359           1.0  0.619261  0.198448
# 4       0.3  0.714286           0.006231           0.0  0.453190  0.319946
#
#       Power  Seats     Brand     Model   Version     Price
# 0  0.045569    0.5  0.600000  0.895735  0.700058  0.008210
# 1  0.174971    0.5  0.333333  0.251185  0.128382  0.075583
# 2  0.103652    0.5  0.300000  0.469194  0.835924  0.025445
# 3  0.103766    0.7  0.600000  0.327014  0.850892  0.034846
# 4  0.202739    0.5  0.033333  0.047393  0.668969  0.108423

# %%
df1.head()
# Out:
#    Location  Year  Kilometers_Driven  Transmission  Mileage  Engine   Power  \
# 0         4  2014              40929             1    32.26   998.0   58.20
# 1         3  2013              54493             1    24.70   796.0   47.30
# 2         9  2017              34000             1    13.68  2393.0  147.80
# 3         5  2012             139000             1    23.59  1364.0   93.70
# 4         9  2014              29000             1    18.50  1197.0   82.85
#
#    Seats  Brand  Model  Version
# 0    4.0     16     15      459
# 1    5.0     16     15      260
# 2    7.0     26     77      360
# 3    5.0     26     59      484
# 4    5.0      9    158      494

# %% [markdown]
# # Train Test Split

# %%
x_test=df1

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:, :-1], 
                                                    df.iloc[:, -1], 
                                                    test_size = 0.3,
                                                    random_state = 42)

# %% [markdown]
# # Training The Model

# %% [markdown]
# ## Linear Regression

# %%
linearRegression = LinearRegression()
linearRegression.fit(X_train, Y_train)
y_train_pred=linearRegression.predict(X_train)
y_pred = linearRegression.predict(X_test)
y_test_pred=linearRegression.predict(x_test)

# %% [markdown]
# ### R2-Score on Train Data

# %%
r2score=r2_score(Y_train,y_train_pred)
print("R2-Score:",r2score)
# Out:
# R2-Score: 0.7333392346735319

# %% [markdown]
# ### R2-Score on Test Data

# %%
r2score=r2_score(Y_test, y_pred)
print("R2-Score:",r2score)
# Out:
# R2-Score: 0.7307849859722835

# %% [markdown]
# ### Errors Obtained After predicting on Train Data

# %%
mae=metrics.mean_absolute_error(Y_train,y_train_pred)
mse=metrics.mean_squared_error(Y_train,y_train_pred)
rms=math.sqrt(mse)
print("Mean Absolute Error:",mae,"\nMean Squared Error:",mse,"\nRoot Mean Squared Error:",rms)
# Out:
# Mean Absolute Error: 0.016854404687321252
# Mean Squared Error: 0.0006187556342441469
# Root Mean Squared Error: 0.024874799179976245

# %% [markdown]
# ### Errors Obtained After predicting on Test Data

# %%
mae=metrics.mean_absolute_error(Y_test, y_pred)
mse=metrics.mean_squared_error(Y_test, y_pred)
rms=math.sqrt(mse)
print("Mean Absolute Error:",mae,"\nMean Squared Error:",mse,"\nRoot Mean Squared Error:",rms)
# Out:
# Mean Absolute Error: 0.017478137111087307
# Mean Squared Error: 0.0006763215581120936
# Root Mean Squared Error: 0.02600618307464772

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestRegressor(n_estimators = 100)
rf.fit(X_train, Y_train)
y_train_pred=rf.predict(X_train)
y_pred = rf.predict(X_test)

# %% [markdown]
# ### R2-Score on Train Data

# %%
r2score=r2_score(Y_train, y_train_pred)
print("R2-Score:",r2score)
# Out:
# R2-Score: 0.9876394025301373

# %% [markdown]
# ### R2-Score on Test Data

# %%
r2score=r2_score(Y_test, y_pred)
print("R2-Score:",r2score)
# Out:
# R2-Score: 0.9163451452939069

# %% [markdown]
# ### Errors Obtained After predicting on Train Data

# %%
mae=metrics.mean_absolute_error(Y_train, y_train_pred)
mse=metrics.mean_squared_error(Y_train, y_train_pred)
rms=math.sqrt(mse)
print("Mean Absolute Error:",mae,"\nMean Squared Error:",mse,"\nRoot Mean Squared Error:",rms)
# Out:
# Mean Absolute Error: 0.0027828239450819344
# Mean Squared Error: 2.868134469552726e-05
# Root Mean Squared Error: 0.0053554966805635556

# %% [markdown]
# ### Errors Obtained After predicting on Test Data

# %%
mae=metrics.mean_absolute_error(Y_test, y_pred)
mse=metrics.mean_squared_error(Y_test, y_pred)
rms=math.sqrt(mse)
print("Mean Absolute Error:",mae,"\nMean Squared Error:",mse,"\nRoot Mean Squared Error:",rms)
# Out:
# Mean Absolute Error: 0.007686174201646652
# Mean Squared Error: 0.00021015760165828218
# Root Mean Squared Error: 0.014496813500155204

# %% [markdown]
# ## Predicting on Original Test Set Using RandomForest Model

# %%
output = rf.predict(x_test)

# %%
output
# Out:
# array([0.14208542, 0.14208542, 0.14208542, ..., 0.14208542, 0.14583135,
#        0.14583135])
